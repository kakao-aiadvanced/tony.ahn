# %% [markdown]
# openai 설치

# %%
# !pip install openai

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass.getpass()
# Out:
# ··········

# %%
# !pip install llmlingua

# %%
from llmlingua import PromptCompressor

# llm_lingua = PromptCompressor(
#     model_name="microsoft/llmlingua-2-xlm-roberta-large-meetingbank",
#     use_llmlingua2=True, # Whether to use llmlingua-2
# )

## Use LLMLingua-2-small model
llm_lingua = PromptCompressor(
    model_name="microsoft/llmlingua-2-bert-base-multilingual-cased-meetingbank",
    use_llmlingua2=True, # Whether to use llmlingua-2
)

# %%
prompt = """
다음과 같은 두 개의 역할이 있어.
첫번째 역할: math teacher
두번째 역할: history teacher
사용자가 질문을 했을 때, 그 질문에 대한 응답 대신 두 역할 중 어떤 역할이 더 답변을 잘할지를 응답해줘.
예) 사용자 입력 : what is the Newton’s law? How did World War I end?
응답 예 : history teacher
"""
compressed_prompt = llm_lingua.compress_prompt(prompt, rate=0.90, force_tokens = ['\n', '?'])
print(compressed_prompt['compressed_prompt_list'][0])
compressed_prompt_msg = compressed_prompt['compressed_prompt_list'][0]
# Out:
#  다음과 같은 두 개의 역할이 있어.
#  첫번째 역할 math teacher
#  두번째 역할 history teacher
#  사용자가 질문을 때 질문에 대한 응답 대신 두 역할 중 어떤 역할이 더 답변을 잘할지를 응답해줘.
#  예 ) 사용자 입력 : Newton s law? World War I end?
#  응답 예 history teacher

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "user", "content": compressed_prompt_msg}
  ]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-26-83d052b96f43> in <cell line: 4>()
#       2 client = OpenAI()
#       3
# ----> 4 completion = client.chat.completions.create(
#       5   model="gpt-4o-mini",
#       6   messages=[
#
# /usr/local/lib/python3.10/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     275                         msg = f"Missing required argument: {quote(missing[0])}"
#     276                 raise TypeError(msg)
# --> 277             return func(*args, **kwargs)
#     278
#     279         return wrapper  # type: ignore
#
# ...

# %%
prompt = """
1부터 n까지 자연수가 있어.
이 중 m개의 list를 입력받은 후 정렬해줘.
예시) n : 10, list: [1,7,4,2]
응답 예시 : [1,2,4,7]
"""
compressed_prompt = llm_lingua.compress_prompt(prompt, rate=0.90, force_tokens = ['\n', '?'])
print(compressed_prompt['compressed_prompt_list'][0])
compressed_prompt_msg = compressed_prompt['compressed_prompt_list'][0]
# Out:
#  1부터 n까지 자연수가 있어
#  m개의 list를 정렬해줘
#  예시 ) n : 10, list : [ 1, 7, 4, 2 ]
#  응답 예시 : [ 1, 2, 4, 7 ]

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "user", "content": compressed_prompt_msg}
  ]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-30-83d052b96f43> in <cell line: 4>()
#       2 client = OpenAI()
#       3
# ----> 4 completion = client.chat.completions.create(
#       5   model="gpt-4o-mini",
#       6   messages=[
#
# /usr/local/lib/python3.10/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     275                         msg = f"Missing required argument: {quote(missing[0])}"
#     276                 raise TypeError(msg)
# --> 277             return func(*args, **kwargs)
#     278
#     279         return wrapper  # type: ignore
#
# ...
